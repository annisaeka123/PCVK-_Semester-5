# %% [markdown]
# <a href="https://colab.research.google.com/github/annisaeka123/PCVK-_Semester-5/blob/main/Week02_Tugas_Kelompok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # TUGAS PRAKTIKUM KELOMPOK
# **Anggota:**
# 1. Annisa Eka Puspita (2)
# 2. Aqsa Herry Prasetya (4)
# 3. Danendra Nayaka Passadhi (7)

# %% [markdown]
# ## Melakukan akses file secara lokal

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
import matplotlib.pyplot as plt

# %% [markdown]
# ## Menutup bagian pada KTM
# Kelompok 1: Bagian NIM dan nama

# %%
img = cv.imread('/content/drive/MyDrive/PCVK/image.png')
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
cv.rectangle(img3, pt1=(750, 1150), pt2=(250, 1200), color=(0,255,0), thickness=cv.FILLED)
plt.imshow(img3)

# %%
cv.rectangle(img3, pt1=(750, 1230), pt2=(240, 1290), color=(0,0,0), thickness=cv.FILLED)
plt.imshow(img3)
